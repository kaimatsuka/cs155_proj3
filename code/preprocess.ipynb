# %%
import keras.preprocessing.text
import nltk.corpus.reader.cmudict
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Tokenize

# %%
file = open('./data/shakespeare.txt', 'r')
text = file.read()
word_sequence = keras.preprocessing.text.text_to_word_sequence(text, filters='0123456789!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ')
Tokenizer = keras.preprocessing.text.Tokenizer(num_words=None, filters='0123456789!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)
Tokenizer.fit_on_texts(word_sequence)
word_counts = Tokenizer.word_counts;
print(word_counts)
# Out:
# OrderedDict([('from', 82), ('fairest', 5), ('creatures', 2), ('we', 15), ('desire', 11), ('increase', 4), ('that', 322), ('thereby', 2), ("beauty's", 18), ('rose', 6), ('might', 26), ('never', 16), ('die', 12), ('but', 163), ('as', 121), ('the', 430), ('riper', 2), ('should', 44), ('by', 92), ('time', 54), ('decease', 3), ('his', 107), ('tender', 7), ('heir', 3), ('bear', 12), ('memory', 8), ('thou', 234), ('contracted', 2), ('to', 414), ('thine', 44), ('own', 30), ('bright', 11), ('eyes', 52), ("feed'st", 1), ('thy', 287), ("light's", 1), ('flame', 3), ('with', 181), ('self', 87), ('substantial', 1), ('fuel', 1), ('making', 12), ('a', 164), ('famine', 1), ('where', 41), ('abundance', 4), ('lies', 12), ('foe', 1), ('sweet', 56), ('too', 18), ('cruel', 8), ('art', 51), ('now', 45), ("world's", 5), ('fresh', 7), ('ornament', 5), ('and', 490), ('only', 6), ('herald', 1), ('gaudy', 1), ('spring', 5), ('within', 11), ('bud', 2), ('buriest', 1), ('content', 2), ('churl', 2), ("mak'st", 2), ('waste', 7), ('in', 323), ('niggarding', 1), ('pity', 9), ('world', 28), ('or', 79), ('else', 5), ('this', 104), ('glutton', 1), ('be', 142), ('eat', 3), ('due', 6), ('grave', 3), ('thee', 162), ('when', 106), ('forty', 1), ('winters', 2), ('shall', 59), ('besiege', 2), ('brow', 8), ('dig', 1), ('deep', 8), ('trenches', 1), ('field', 1), ("youth's", 1), ('proud', 14), ('livery', 1), ('so', 145), ('gazed', 1), ('on', 80), ('will', 59), ('tattered', 2), ('weed', 3), ('of', 370), ('small', 2), ('worth', 19), ('held', 2), ('then', 74), ('being', 32), ('asked', 1), ('all', 120), ('beauty', 52), ('treasure', 9), ('lusty', 2), ('days', 17), ('say', 28), ('sunken', 1), ('were', 29), ('an', 17), ('eating', 1), ('shame', 10), ('thriftless', 1), ('praise', 28), ('how', 40), ('much', 17), ('more', 64), ('deserved', 1), ('use', 13), ('if', 68), ('couldst', 1), ('answer', 3), ("'this", 1), ('fair', 44), ('child', 8), ('mine', 63), ('sum', 4), ('my', 394), ('count', 4), ('make', 43), ('old', 22), ("excuse'", 1), ('proving', 1), ('succession', 1), ('new', 26), ('made', 19), ('see', 35), ('blood', 8), ('warm', 1), ("feel'st", 1), ('it', 111), ('cold', 7), ('look', 22), ('glass', 10), ('tell', 15), ('face', 19), ('viewest', 1), ('is', 168), ('form', 11), ('another', 9), ('whose', 19), ('repair', 3), ('not', 166), ('renewest', 1), ('dost', 29), ('beguile', 1), ('unbless', 1), ('some', 31), ('mother', 2), ('for', 171), ('she', 33), ('uneared', 1), ('womb', 2), ('disdains', 1), ('tillage', 1), ('husbandry', 2), ('who', 29), ('he', 43), ('fond', 2), ('tomb', 5), ('love', 167), ('stop', 2), ('posterity', 3), ("mother's", 3), ('calls', 5), ('back', 9), ('lovely', 8), ('april', 3), ('her', 51), ('prime', 4), ('through', 7), ('windows', 3), ('age', 15), ('shalt', 11), ('despite', 6), ('wrinkles', 5), ('golden', 5), ('live', 29), ('remembered', 4), ('single', 4), ('image', 4), ('dies', 1), ('unthrifty', 1), ('loveliness', 1), ('why', 25), ('spend', 5), ('upon', 29), ('legacy', 1), ("nature's", 6), ('bequest', 1), ('gives', 8), ('nothing', 19), ('doth', 88), ('lend', 5), ('frank', 1), ('lends', 4), ('those', 33), ('are', 69), ('free', 4), ('beauteous', 9), ('niggard', 2), ('abuse', 3), ('bounteous', 2), ('largess', 1), ('given', 4), ('give', 27), ('profitless', 1), ('usurer', 2), ('great', 10), ('sums', 1), ('yet', 51), ('canst', 7), ('having', 6), ('traffic', 1), ('alone', 19), ('deceive', 2), ('nature', 10), ('gone', 9), ('what', 70), ('acceptable', 1), ('audit', 3), ('leave', 10), ('unused', 4), ('must', 21), ('tombed', 1), ('which', 108), ('used', 4), ('lives', 9), ("th'", 9), ('executor', 1), ('hours', 12), ('gentle', 14), ('work', 3), ('did', 26), ('frame', 4), ('gaze', 2), ('every', 29), ('eye', 37), ('dwell', 6), ('play', 5), ('tyrants', 1), ('very', 7), ('same', 7), ('unfair', 1), ('fairly', 1), ('excel', 1), ('resting', 1), ('leads', 2), ('summer', 8), ('hideous', 2), ('winter', 5), ('confounds', 3), ('him', 38), ('there', 18), ('sap', 2), ('checked', 2), ('frost' ...

# %% [markdown]
# # Syllable Dictionary
